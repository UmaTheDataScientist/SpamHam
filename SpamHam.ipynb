# %%
#Import statements
import pandas as pd

# %%
# Reading csv
data = pd.read_csv("spam.csv",encoding = 'latin-1')

# %%
data
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
#Better visualization for number of rows and columns

# %%
#I see that there are three unnamed columns at the end. 

#Check for non-missing values in those three columns. If all the values are missing, we drop the last three columns. 

#we'll take this chance to understand if the first two columns have missing values as well.

# %%
#Missing value check
data.notnull().sum()
# Out:
# v1            5572
# v2            5572
# Unnamed: 2      50
# Unnamed: 3      12
# Unnamed: 4       6
# dtype: int64

# %%
#There are some values in unnamed: 2,3,4. Let's check them out
data.loc[data['Unnamed: 2'].notnull()]
# Out:
#         v1                                                 v2  \
# 95    spam  Your free ringtone is waiting to be collected....
# 281    ham                                \Wen u miss someone
# 444    ham  \HEY HEY WERETHE MONKEESPEOPLE SAY WE MONKEYAR...
# 671   spam         SMS. ac sun0819 posts HELLO:\You seem cool
# 710    ham  Height of Confidence: All the Aeronautics prof...
# 899   spam  Your free ringtone is waiting to be collected....
# 1038   ham  Edison has rightly said, \A fool can ask more ...
# 1127   ham  Height of \Oh shit....!!\" situation: A guy th...
# 1266   ham    \Hey sorry I didntgive ya a a bellearlier hunny
# 1384   ham  Storming msg: Wen u lift d phne, u say \HELLO\...
# 1428   ham  Tell you what, if you make a little spreadshee...
# 1559   ham  Single line with a big meaning::::: \Miss anyt...
# 1637  spam  0A$NETWORKS allow companies to bill for SMS, s...
# 1669   ham  Very hurting n meaningful lines ever: \I compr...
# ...

# %%
#To be honest, I don't quite understand the use of these columns. Maybe they are characters in another paragraph
#I'm gonna delete these columns for that reason.

# %%
#Deleting columns Unnamed:2,3,4
data.drop(['Unnamed: 2', 'Unnamed: 3','Unnamed: 4'], axis=1, inplace=True)

# %%
data.head()
#This looks okay now.
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
#There's gotta be some text mining to do here to identify the patterns.
